# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %% [markdown]
# #Uber-Trip-Analysis -> Data Cleaning
# ##Objective:
# To prepare the dataset for analysis by formatting the data correctly and engineering useful metrics, ensuring it is clean, consistent, and ready for further exploration.

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as

# %%
df = pd.read_csv('/content/drive/MyDrive/uberTripAnalysis/data/raw.csv')

# %%
df['date'] = pd.to_datetime(df['date'])

# %%
df.isna().sum()
# Out:
# dispatching_base_number    0
# date                       0
# active_vehicles            0
# trips                      0
# dtype: int64

# %%
df['trips_per_driver'] = df['trips']/df['active_vehicles']

# %%
df.head()
# Out:
#   dispatching_base_number       date  active_vehicles  trips  trips_per_driver
# 0                  B02512 2015-01-01              190   1132          5.957895
# 1                  B02765 2015-01-01              225   1765          7.844444
# 2                  B02764 2015-01-01             3427  29421          8.585060
# 3                  B02682 2015-01-01              945   7679          8.125926
# 4                  B02617 2015-01-01             1228   9537          7.766287
# <h4 class="colab-quickchart-section-title">Distributions</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# from matplotlib import pyplot as plt
# _df_0['active_vehicles'].plot(kind='hist', bins=20, title='active_vehicles')
# plt.gca().spines[['top', 'right',]].set_visible(False)
# from matplotlib import pyplot as plt
# _df_1['trips'].plot(kind='hist', bins=20, title='trips')
# plt.gca().spines[['top', 'right',]].set_visible(False)
# ...

# %%
df.isna().sum()
# Out:
# dispatching_base_number    0
# date                       0
# active_vehicles            0
# trips                      0
# trips_per_driver           0
# dtype: int64

# %%
df.duplicated().sum()
# Out:
# np.int64(0)

# %%
df.to_csv('/content/drive/MyDrive/uberTripAnalysis/data/cleaned.csv',index = False)

# %% [markdown]
# **Successfully validated that the dataset contains no missing or duplicate records, converted the date column into a usable format, and created a new trips_per_driver feature.**
